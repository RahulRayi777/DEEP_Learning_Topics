# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.chdir(r'C:\Users\63094\Downloads\hero wired\datacsv')
os.listdir();

# %%
df=pd.read_csv('Churn.csv')
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
df.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.isna().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %% [markdown]
# ### object variables can be converted into the numerical....

# %%
df.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70550        0.515100    100090.239881      0.203700
# std        0.45584        0.499797     57510.492818      0.402769
# ...

# %%
sns.boxplot(df['Balance'])
# Out:
# C:\Users\63094\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Balance'>

# %%
df.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.tail(10)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 9990          714   Germany    Male   33       3   35016.60              1
# 9991          597    France  Female   53       4   88381.21              1
# 9992          726     Spain    Male   36       2       0.00              1
# 9993          644    France    Male   28       7  155060.41              1
# 9994          800    France  Female   29       2       0.00              2
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 9990          1               0         53667.08       0
# ...

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df=pd.get_dummies(df,drop_first=True)
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1                  0
# ...

# %% [markdown]
# ### now we convertd to numerical

# %% [markdown]
# ### apply scaling to the dataset so it can in one portion

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split

# %%
x=df.drop(columns=['Exited'])
y=df['Exited']

# %%
x.shape
# Out:
# (10000, 11)

# %%
y.shape
# Out:
# (10000,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
s=StandardScaler()

# %%
x_train_scale=s.fit_transform(x_train)
x_test_scale=s.fit_transform(x_test)

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(11,activation='sigmoid',input_dim=11))
model.add(Dense(8,activation='sigmoid',input_dim=6))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 11)                132
#
#  dense_1 (Dense)             (None, 8)                 96
#
#  dense_2 (Dense)             (None, 1)                 9
#
# ...
# Total params: 237
# Trainable params: 237
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam',
    loss='binary_crossentropy',
    metrics=['accuracy'])

# %%
m=model.fit(x_train_scale,y_train,epochs=40,validation_split=0.2)
# Out:
# Epoch 1/40
# 175/175 [==============================] - 0s 2ms/step - loss: 0.4282 - accuracy: 0.8089 - val_loss: 0.4408 - val_accuracy: 0.7979
# Epoch 2/40
# 175/175 [==============================] - 0s 2ms/step - loss: 0.4272 - accuracy: 0.8082 - val_loss: 0.4405 - val_accuracy: 0.8043
# Epoch 3/40
# 175/175 [==============================] - 0s 2ms/step - loss: 0.4264 - accuracy: 0.8089 - val_loss: 0.4401 - val_accuracy: 0.8057
# Epoch 4/40
# 175/175 [==============================] - 0s 2ms/step - loss: 0.4254 - accuracy: 0.8118 - val_loss: 0.4382 - val_accuracy: 0.8000
# Epoch 5/40
# 175/175 [==============================] - 0s 3ms/step - loss: 0.4246 - accuracy: 0.8125 - val_loss: 0.4380 - val_accuracy: 0.8043
# Epoch 6/40
# 175/175 [==============================] - 0s 3ms/step - loss: 0.4237 - accuracy: 0.8132 - val_loss: 0.4370 - val_accuracy: 0.8043
# Epoch 7/40
# ...

# %%
m.history
# Out:
# {'loss': [0.4282064735889435,
#   0.4271543622016907,
#   0.42635276913642883,
#   0.4254102110862732,
#   0.42460790276527405,
#   0.4237094521522522,
#   0.42262765765190125,
#   0.421580970287323,
#   0.4208524525165558,
#   0.419902503490448,
#   0.41897574067115784,
#   0.41801971197128296,
#   0.4171164333820343,
#   0.4164087772369385,
#   0.41555851697921753,
#   0.4148801863193512,
#   0.41402000188827515,
#   0.4133552312850952,
#   0.41288354992866516,
#   0.4121266007423401,
#   0.4114583432674408,
#   0.41088369488716125,
#   0.41034916043281555,
#   0.4098897874355316,
#   0.40935996174812317,
#   0.40892454981803894,
#   0.40836530923843384,
#   0.40817442536354065,
#   0.4076438546180725,
#   0.40744850039482117,
#   0.40700483322143555,
#   0.40660718083381653,
#   0.4062088131904602,
#   0.40610164403915405,
#   0.405875027179718,
#   0.40564653277397156,
#   0.40500614047050476,
#   0.40491268038749695,
#   0.40468114614486694,
#   0.40440133213996887],
# ...

# %%
plt.plot(m.history['loss'])
 
plt.show()

# %%
 y_pred=np.where(model.predict(x_test_scale)>0.5,1,0)
# Out:
# 94/94 [==============================] - 0s 918us/step

# %%
from sklearn.metrics import  accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.843
