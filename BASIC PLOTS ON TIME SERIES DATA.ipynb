# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.chdir(r'C:\Users\63094\Downloads\hero wired\datacsv')
os.listdir();

# %%
df=pd.read_csv('times_series1.csv', index_col=0)
df
# Out:
#                 value
# date
# 1991-07-01   3.526591
# 1991-08-01   3.180891
# 1991-09-01   3.252221
# 1991-10-01   3.611003
# 1991-11-01   3.565869
# ...               ...
# 2008-02-01  21.654285
# 2008-03-01  18.264945
# 2008-04-01  23.107677
# 2008-05-01  22.912510
# 2008-06-01  19.431740
#
# [204 rows x 1 columns]

# %% [markdown]
# ### we indexed by using the date

# %%
df['value']
# Out:
# date
# 1991-07-01     3.526591
# 1991-08-01     3.180891
# 1991-09-01     3.252221
# 1991-10-01     3.611003
# 1991-11-01     3.565869
#                 ...
# 2008-02-01    21.654285
# 2008-03-01    18.264945
# 2008-04-01    23.107677
# 2008-05-01    22.912510
# 2008-06-01    19.431740
# Name: value, Length: 204, dtype: float64

# %%
df.shape
# Out:
# (204, 1)

# %%
df.describe()
# Out:
#             value
# count  204.000000
# mean    10.694430
# std      5.956998
# min      2.814520
# 25%      5.844095
# 50%      9.319345
# 75%     14.289964
# max     29.665356

# %%
a=df['value']

# %%
a
# Out:
# date
# 1991-07-01     3.526591
# 1991-08-01     3.180891
# 1991-09-01     3.252221
# 1991-10-01     3.611003
# 1991-11-01     3.565869
#                 ...
# 2008-02-01    21.654285
# 2008-03-01    18.264945
# 2008-04-01    23.107677
# 2008-05-01    22.912510
# 2008-06-01    19.431740
# Name: value, Length: 204, dtype: float64

# %%
# %matplotlib notebook
plt.plot(a,label='val')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('time-series')
plt.grid()
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
#   ### changing the dpi of the image in matplotlib

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi']=100

# %% [markdown]
# ### NOW SEEEING THE DIFFERRENT COMPONENTS OF TIME SERIES

# %%
os.listdir();

# %%
df2=pd.read_csv('times_series2.csv',index_col=0)
df3=pd.read_csv('times_series3.csv',index_col=0)
df4=pd.read_csv('times_series4.csv',index_col=0)

# %%
df2.head()
# Out:
#                value
# date
# 1970-01-01  0.311405
# 1971-01-01  0.325180
# 1972-01-01  0.339565
# 1973-01-01  0.354580
# 1974-01-01  0.370265

# %%
b=df2['value']

# %%
df3
# Out:
#                  value
# date
# 1875-01-01  213.133333
# 1876-01-01  109.283333
# 1877-01-01   92.858333
# 1878-01-01   22.216667
# 1879-01-01   36.333333
# ...                ...
# 2007-01-01  133.341667
# 2008-01-01   22.808333
# 2009-01-01   26.558333
# 2010-01-01  214.291667
# 2011-01-01  749.566667
#
# [137 rows x 1 columns]

# %%
df4
# Out:
#             value
# date
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# ...           ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
#
# [144 rows x 1 columns]

# %%
# %matplotlib notebook
plt.plot(b,label='fb')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('2nd df plot')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
c=df3['value']

# %%
# %matplotlib notebook
plt.plot(c,label='fb')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('3rd df plot')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
d=df4['value']
# %matplotlib notebook
plt.plot(d,label='fb')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('4td df plot')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
